# %%
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np

import scipy.stats as stats

import uproot

# %%
def add_gaussian(arr, ax):
    mu, sigma = np.mean(arr), np.std(arr)
    x = np.linspace(mu-3*sigma, mu+3*sigma, 1000)
    ax.plot(x, stats.norm.pdf(x, mu, sigma))

# %%
def plot_helper(ax, arrays, names, bins=100, sym_range=10.0):
    for array, name in zip(arrays, names):
        array = array[~np.isnan(array)]
        array = array[ abs(array) < sym_range ]
        _, bins, _ = ax.hist(array, bins=bins, histtype="step", label=f"{name} (mu={np.mean(array):.3f}, sigma={np.std(array):.3f})")
        #add_gaussian(pull, plt.gca())
    
    ax.legend()

# %%
def ec(array):
    return np.concatenate(array.array(library="np"))

# %%
base_dir = Path("../tmp")

# %%
tracksummary_kf = base_dir / "10GeV/tracksummary_kalman.root"
tracksummary_kf = uproot.open(str(tracksummary_kf) + ":tracksummary")

tracksummary_gsf_refit = base_dir / "10GeV/tracksummary_gsf_refit.root"
tracksummary_gsf_refit = uproot.open(str(tracksummary_gsf_refit) + ":tracksummary")

# %%
_ = plt.hist(event_concat(tracksummary_kf["t_theta"]))

# %%
print(tracksummary_kf.keys())
# Out:
# ['event_nr', 'track_nr', 'nStates', 'nMeasurements', 'nOutliers', 'nHoles', 'nSharedHits', 'chi2Sum', 'NDF', 'measurementChi2', 'outlierChi2', 'measurementVolume', 'measurementLayer', 'outlierVolume', 'outlierLayer', 'nMajorityHits', 'majorityParticleId', 'trackClassification', 't_charge', 't_time', 't_vx', 't_vy', 't_vz', 't_px', 't_py', 't_pz', 't_theta', 't_phi', 't_eta', 't_p', 't_pT', 't_d0', 't_z0', 'hasFittedParams', 'eLOC0_fit', 'eLOC1_fit', 'ePHI_fit', 'eTHETA_fit', 'eQOP_fit', 'eT_fit', 'err_eLOC0_fit', 'err_eLOC1_fit', 'err_ePHI_fit', 'err_eTHETA_fit', 'err_eQOP_fit', 'err_eT_fit', 'res_eLOC0_fit', 'res_eLOC1_fit', 'res_ePHI_fit', 'res_eTHETA_fit', 'res_eQOP_fit', 'res_eT_fit', 'pull_eLOC0_fit', 'pull_eLOC1_fit', 'pull_ePHI_fit', 'pull_eTHETA_fit', 'pull_eQOP_fit', 'pull_eT_fit']

# %%
pull_kf = np.concatenate(tracksummary_kf["pull_eQOP_fit"].array(library="np"))
pull_gsf_refit = np.concatenate(tracksummary_gsf_refit["pull_eQOP_fit"].array(library="np"))

_, ax = plt.subplots()
plot_helper(ax, [pull_kf, pull_gsf_refit], ["KF", "GSF refit"])
ax.set_title("Pulls")
# Out:
# Text(0.5, 1.0, 'Pulls')

# %%
res_kf = np.concatenate(tracksummary_kf["res_eQOP_fit"].array(library="np"))
res_gsf_refit = np.concatenate(tracksummary_gsf_refit["res_eQOP_fit"].array(library="np"))

fig, ax = plt.subplots()
plot_helper(ax, [res_kf, res_gsf_refit], ["KF", "GSF refit"], sym_range=0.1)
ax.set_title("Residuals")
# Out:
# Text(0.5, 1.0, 'Residuals')

# %%
res_kf = np.concatenate(tracksummary_kf["res_eQOP_fit"].array(library="np"))
res_gsf_refit = np.concatenate(tracksummary_gsf_refit["res_eQOP_fit"].array(library="np"))

fig, ax = plt.subplots()
plot_helper(ax, [res_kf, res_gsf_refit], ["KF", "GSF refit"], sym_range=0.1, bins=100)
ax.set_title("Residuals")
# Out:
# Text(0.5, 1.0, 'Residuals')

# %%
def pt_res_q_over_pt(summary):
    true_qopT = summary["t_charge"]/summary["t_pT"]
    reco_qopT = summary["eQOP_fit"] * (1/np.sin
